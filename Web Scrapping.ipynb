# %%
import requests

# %%
import bs4

# %%
res = requests.get("https://en.wikipedia.org/wiki/Deep_Blue_(chess_computer)")

# %%
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
image_info = soup.select('img')

# %%
comp=image_info[0]

# %%
comp['src']
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/b/be/Deep_Blue.jpg/220px-Deep_Blue.jpg'

# %% [markdown]
# <img src="//upload.wikimedia.org/wikipedia/commons/thumb/b/be/Deep_Blue.jpg/220px-Deep_Blue.jpg">

# %%
import requests
import bs4

# %%
res= requests.get("http://quotes.toscrape.com/")

# %%
res.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<meta charset="UTF-8">\n\t<title>Quotes to Scrape</title>\n    <link rel="stylesheet" href="/static/bootstrap.min.css">\n    <link rel="stylesheet" href="/static/main.css">\n</head>\n<body>\n    <div class="container">\n        <div class="row header-box">\n            <div class="col-md-8">\n                <h1>\n                    <a href="/" style="text-decoration: none">Quotes to Scrape</a>\n                </h1>\n            </div>\n            <div class="col-md-4">\n                <p>\n                \n                    <a href="/login">Login</a>\n                \n                </p>\n            </div>\n        </div>\n    \n\n<div class="row">\n    <div class="col-md-8">\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>\n        <
# ...

# %%
soup= bs4.BeautifulSoup(res.text,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Quotes to Scrape</title>
# <link href="/static/bootstrap.min.css" rel="stylesheet"/>
# <link href="/static/main.css" rel="stylesheet"/>
# </head>
# <body>
# <div class="container">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
# ...

# %%
 soup.select('.author')
# Out:
# [<small class="author" itemprop="author">Albert Einstein</small>,
#  <small class="author" itemprop="author">J.K. Rowling</small>,
#  <small class="author" itemprop="author">Albert Einstein</small>,
#  <small class="author" itemprop="author">Jane Austen</small>,
#  <small class="author" itemprop="author">Marilyn Monroe</small>,
#  <small class="author" itemprop="author">Albert Einstein</small>,
#  <small class="author" itemprop="author">André Gide</small>,
#  <small class="author" itemprop="author">Thomas A. Edison</small>,
#  <small class="author" itemprop="author">Eleanor Roosevelt</small>,
#  <small class="author" itemprop="author">Steve Martin</small>]

# %%
authors= []
for i in  soup.select('.author'):
    authors.append(i.text)

# %%
set(authors)
# Out:
# {'Albert Einstein',
#  'André Gide',
#  'Eleanor Roosevelt',
#  'J.K. Rowling',
#  'Jane Austen',
#  'Marilyn Monroe',
#  'Steve Martin',
#  'Thomas A. Edison'}

# %%
quotes= []
for i in soup.select('.text'):
    quotes.append(i.text)

# %%
soup.select('.text')
# Out:
# [<span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>,
#  <span class="text" itemprop="text">“It is our choices, Harry, that show what we truly are, far more than our abilities.”</span>,
#  <span class="text" itemprop="text">“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”</span>,
#  <span class="text" itemprop="text">“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”</span>,
#  <span class="text" itemprop="text">“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”</span>,
#  <span class="text" itemprop="text">“Try not to become a man of success. Rather become a man of value.”</span>,
# ...

# %%
quotes
# Out:
# ['“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”',
#  '“It is our choices, Harry, that show what we truly are, far more than our abilities.”',
#  '“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”',
#  '“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”',
#  "“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”",
#  '“Try not to become a man of success. Rather become a man of value.”',
#  '“It is better to be hated for what you are than to be loved for what you are not.”',
#  "“I have not failed. I've just found 10,000 ways that won't work.”",
#  "“A woman is like a tea bag; you never know how strong it is until it's in hot water.”",
#  '“A day without sunshine is like, you know, night.”']

# %%
for i in soup.select('.tag-item'):
    print(i.text)
# Out:
# love
#
#
# inspirational
#
#
# life
#
#
# humor
#
#
# books
#
#
# reading
#
#
# friendship
#
#
# friends
#
#
# truth
#
#
# simile

# %%
import requests
import bs4

# %%
URL = 'https://chartink.com/screener/time-pass-48'
page = requests.get(URL)
print(page)

soup = bs4.BeautifulSoup(page.content, 'html.parser')
print(soup)
# Out:
# <Response [200]>
# <!DOCTYPE html>
#
# <html class="" lang="en">
# <head>
# ...

# %%
table = soup.select('.table.table.striped.scan.results.table.dataTable.no.footerd')

# %%
table
# Out:
# []

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

data = {
  'scan_clause': '( {cash} ( monthly rsi( 14 ) > 60 and weekly rsi( 14 ) > 60 and latest rsi( 14 ) > 60 and 1 day ago  rsi( 14 ) <= 60 and latest volume > 100000 ) ) '
}

with requests.Session() as s:
    r = s.get('https://chartink.com/screener/time-pass-48')
    soup = bs(r.content, 'lxml')
    s.headers['X-CSRF-TOKEN'] = soup.select_one('[name=csrf-token]')['content']
    r = s.post('https://chartink.com/screener/process', data=data).json()
    #print(r.json())
    df = pd.DataFrame(r['data'])
    print(df)
# Out:
#     sr     nsecode                                           name bsecode  \
# 0    1       DMART                              Avenue Supermarts  540376
# 1    2   RATNAMANI               Ratnamani Metals & Tubes Limited  520111
# 2    3      ASTRAL                    Astral Poly Technik Limited  532830
# 3    4  POWERINDIA                                     POWERINDIA    None
# 4    5  FLUOROCHEM                                     FLUOROCHEM    None
# 5    6  NATCOPHARM                           Natco Pharma Limited  524816
# 6    7     SBILIFE                 SBI Life Insurance Company Ltd  540719
# 7    8  COROMANDEL               Coromandel International Limited  506395
# 8    9  CUMMINSIND                          Cummins India Limited  500480
# 9   10      CYIENT                                 Cyient Limited  532175
# 10  11  PRINCEPIPE                                     PRINCEPIPE    None
# 11  12      CONCOR         Container Corporation Of India Limited  531344
# ...

# %%
import requests
import bs4

# %%
res= requests.get("https://aiwa.ae/category/building-materials-trading")

# %%
res.text
# Out:
# '\r\n<!DOCTYPE html>\r\n<!--[if lt IE 7]> <html lang="en" class="no-js ie6"> <![endif]-->\r\n<!--[if IE 7]>    <html lang="en" class="no-js ie7"> <![endif]-->\r\n<!--[if IE 8]> <html lang="en" class="ie8 no-js"> <![endif]-->\r\n<!--[if IE 9]> <html lang="en" class="ie9 no-js"> <![endif]-->\r\n<!--[if !IE]><!-->\r\n<html lang="en" data-ng-app="app">\r\n<!--<![endif]-->\r\n<head>\r\n    <meta charset="utf-8">\r\n    <title>List of Building Materials Suppliers and Services in Dubai |Aiwa UAE</title>\r\n    <!--[if IE]>\r\n        <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\r\n    <![endif]-->\r\n    <meta name="viewport" content="width=device-width initial-scale=1 maximum-scale=1 user-scalable=0">\r\n    <meta name="distribution" content="global" />\r\n    <meta name="language" content="en" />\r\n    <meta name="description" content="Find Building Materials suppliers in Dubai &amp; UAE from online business directory. Check out complete list of Building Material comp
# ...

# %%
soup = bs4.BeautifulSoup(res.text,"lxml")

# %%
soup.select('.ng-binding')
# Out:
# []

# %%
soup
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html lang="en" class="no-js ie6"> <![endif]--><!--[if IE 7]>    <html lang="en" class="no-js ie7"> <![endif]--><!--[if IE 8]> <html lang="en" class="ie8 no-js"> <![endif]--><!--[if IE 9]> <html lang="en" class="ie9 no-js"> <![endif]--><!--[if !IE]><!--><html data-ng-app="app" lang="en">
# <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <title>List of Building Materials Suppliers and Services in Dubai |Aiwa UAE</title>
# <!--[if IE]>
#         <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
#     <![endif]-->
# <meta content="width=device-width initial-scale=1 maximum-scale=1 user-scalable=0" name="viewport"/>
# <meta content="global" name="distribution"/>
# <meta content="en" name="language"/>
# <meta content="Find Building Materials suppliers in Dubai &amp; UAE from online business directory. Check out complete list of Building Material companies in Emirates on aiwa.ae." name="description"/>
# ...

# %%
comp=soup.select(".phoneNumber")

# %%
comp
# Out:
# [<li class="phoneNumber">
#  <a href="tel:+9712 6666724">
#  <i class="fa fa-phone"></i>+9712 6666724
#                              </a>
#  </li>,
#  <li class="phoneNumber">
#  <a href="tel:+971 2 5503336">
#  <i class="fa fa-phone"></i>+971 2 5503336
#                              </a>
#  </li>,
#  <li class="phoneNumber">
#  <a href="tel:+971 4 294 7959">
#  <i class="fa fa-phone"></i>+971 4 294 7959
#                              </a>
#  </li>,
#  <li class="phoneNumber">
#  <a href="tel:+971  4 2586192">
#  <i class="fa fa-phone"></i>+971  4 2586192
#                              </a>
#  </li>,
#  <li class="phoneNumber">
#  <a href="tel:+971 50 699 0325">
#  <i class="fa fa-phone"></i>+971 50 699 0325
#                              </a>
#  </li>,
#  <li class="phoneNumber">
#  <a href="tel:+971 4 2690215">
#  <i class="fa fa-phone"></i>+971 4 2690215
#                              </a>
#  </li>,
#  <li class="phoneNumber">
#  <a href="tel:+971 6 7439693">
# ...

# %%
for i in comp:
    print(i.text)
# Out:
# +9712 6666724
#
#
#
#
# +971 2 5503336
#
#
#
#
# +971 4 294 7959
#
#
#
#
# +971  4 2586192
#
#
#
#
# +971 50 699 0325
#
#
#
#
# +971 4 2690215
#
#
#
#
# +971 6 7439693
#
#
#
#
# +971 4 2895566
#
#
#
#
# +971 4 3402244
#
#
#
#
# +97126786783
#
#
#
#
# +971 4 2277201
#
#
#
#
# +971 4 2364114
#
#
#
#
# +971 2 6437220
#
#
#
#
# +971 4 4480200
#
#
#
#
# +971 2 6334425
#
#
#
#
# +971 2 5548641
#
#
#
#
# +971 6 5337338
#
#
#
#
# +971 4 2340223
#
#
#
#
# +971 2 6789956
#
#
#
#
# +971 4 2589010
#
#
#
# +{{item.primaryPhone}}
